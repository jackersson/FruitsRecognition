# %%
import numpy as np
import cv2
import math
import os
import shutil
import random

#display results
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %% [markdown]
# # Images is about numbers

# %%
filename = "groot.png"

image = cv2.imread(filename)

plt.imshow(image)
plt.show()

# %%
some_part = image[60:95, 20:35, 0]

# %%
print (some_part)
# Out:
# [[ 78  78  79  80  78  78  79  80  82  85  90  90  92  96  95]
#  [ 82  82  81  80  79  78  78  80  84  87  89  90  96  97  91]
#  [ 82  83  82  82  81  79  79  82  86  88  89  89  91  90  82]
#  [ 85  86  86  85  83  80  81  85  87  88  90  89  86  85  77]
#  [ 90  90  88  87  85  84  87  92  93  86  83  77  83  87  88]
#  [ 90  90  89  88  88  80  69  81  88  86  85  79  79  84  91]
#  [ 90  90  90  89  89  79  69  82  94  98  99  88  75  82  92]
#  [ 89  90  90  90  90  86  89  99 104 102 100  85  69  77  89]
#  [ 87  89  89  88  87  90  97  96  90  72  58  66  67  68  83]
#  [ 87  88  88  87  86  86  79  67  50  68  87  55  58  72  85]
#  [ 79  79  75  80  88  80  81  74  42  40  44  36  54  74  83]
#  [ 61  73  65  53  66  74  71  86  63   0   7  26  66  78  84]
#  [ 57  68  80  54  41  48  48  55  37  27  23  25  79  91  90]
#  [ 75  39  54  94  63  35  60  29   5  29  58  58  90  95  92]
#  [ 95  68  44  86  72  42  78  21   0  39  91  88  96  93  89]
# ...

# %%
plt.imshow(some_part)
plt.show()

# %%
Show Filters (examples)

# %%
Show Features (examples)

# %%
Show neural network filters (examples)
